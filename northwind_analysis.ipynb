# %% [markdown]
# ### which customers generate the highest revenue , and what is their city-wise distribution.

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine(
    "mysql+pymysql://root:Durgesh821@localhost:3306/northwind"
)

customers = pd.read_sql("select * from customers",engine)

print(customers.columns)
customers.head()
# Out:
# Index(['id', 'company', 'last_name', 'first_name', 'email_address',
#        'job_title', 'business_phone', 'home_phone', 'mobile_phone',
#        'fax_number', 'address', 'city', 'state_province', 'zip_postal_code',
#        'country_region', 'web_page', 'notes', 'attachments'],
#       dtype='object')
#    id    company         last_name first_name email_address  \
# 0   1  Company A            Bedecs       Anna          None
# 1   2  Company B  Gratacos Solsona    Antonio          None
# 2   3  Company C              Axen     Thomas          None
# 3   4  Company D               Lee  Christina          None
# 4   5  Company E         O’Donnell     Martin          None
#
#                    job_title business_phone home_phone mobile_phone  \
# 0                      Owner  (123)555-0100       None         None
# 1                      Owner  (123)555-0100       None         None
# 2  Purchasing Representative  (123)555-0100       None         None
# 3         Purchasing Manager  (123)555-0100       None         None
# 4                      Owner  (123)555-0100       None         None
#
#       fax_number         address         city state_province zip_postal_code  \
# 0  (123)555-0101  123 1st Street      Seattle             WA           99999
# 1  (123)555-0101  123 2nd Street       Boston             MA           99999
# 2  (123)555-0101  123 3rd Street  Los Angelas             CA           99999
# 3  (123)555-0101  123 4th Street     New York             NY           99999
# 4  (123)555-0101  123 5th Street  Minneapolis             MN           99999
#
#   country_region web_page notes attachments
# 0            USA     None  None         b''
# 1            USA     None  None         b''
# 2            USA     None  None         b''
# 3            USA     None  None         b''
# 4            USA     None  None         b''

# %%
orders = pd.read_sql("select * from orders",engine)
orders.head()
# Out:
#    id  employee_id  customer_id order_date shipped_date  shipper_id  \
# 0  30            9           27 2006-01-15   2006-01-22         2.0
# 1  31            3            4 2006-01-20   2006-01-22         1.0
# 2  32            4           12 2006-01-22   2006-01-22         2.0
# 3  33            6            8 2006-01-30   2006-01-31         3.0
# 4  34            9            4 2006-02-06   2006-02-07         3.0
#
#             ship_name     ship_address  ship_city ship_state_province  \
# 0           Karen Toh  789 27th Street  Las Vegas                  NV
# 1       Christina Lee   123 4th Street   New York                  NY
# 2        John Edwards  123 12th Street  Las Vegas                  NV
# 3  Elizabeth Andersen   123 8th Street   Portland                  OR
# 4       Christina Lee   123 4th Street   New York                  NY
#
#   ship_zip_postal_code ship_country_region  shipping_fee  taxes payment_type  \
# 0                99999                 USA         200.0    0.0        Check
# 1                99999                 USA           5.0    0.0  Credit Card
# 2                99999                 USA           5.0    0.0  Credit Card
# 3                99999                 USA          50.0    0.0  Credit Card
# 4                99999                 USA           4.0    0.0        Check
#
#    paid_date notes  tax_rate tax_status_id  status_id
# 0 2006-01-15  None       0.0          None          3
# 1 2006-01-20  None       0.0          None          3
# 2 2006-01-22  None       0.0          None          3
# 3 2006-01-30  None       0.0          None          3
# 4 2006-02-06  None       0.0          None          3

# %%
order_details = pd.read_sql("select * from order_details",engine)
order_details.head()
# Out:
#    id  order_id  product_id  quantity  unit_price  discount  status_id  \
# 0  27        30          34     100.0        14.0       0.0          2
# 1  28        30          80      30.0         3.5       0.0          2
# 2  29        31           7      10.0        30.0       0.0          2
# 3  30        31          51      10.0        53.0       0.0          2
# 4  31        31          80      10.0         3.5       0.0          2
#
#   date_allocated  purchase_order_id  inventory_id
# 0           None               96.0          83.0
# 1           None                NaN          63.0
# 2           None                NaN          64.0
# 3           None                NaN          65.0
# 4           None                NaN          66.0

# %%
merged = orders.merge(
    order_details,
    left_on="id",
    right_on="order_id",
    suffixes=("_order", "_detail")
)

merged = merged.merge(
    customers,
    left_on="customer_id",
    right_on="id",
    suffixes=("", "_customer")

)

merged.head()
# Out:
#    id_order  employee_id  customer_id order_date shipped_date  shipper_id  \
# 0        30            9           27 2006-01-15   2006-01-22         2.0
# 1        30            9           27 2006-01-15   2006-01-22         2.0
# 2        31            3            4 2006-01-20   2006-01-22         1.0
# 3        31            3            4 2006-01-20   2006-01-22         1.0
# 4        31            3            4 2006-01-20   2006-01-22         1.0
#
#        ship_name     ship_address  ship_city ship_state_province  ...  \
# 0      Karen Toh  789 27th Street  Las Vegas                  NV  ...
# 1      Karen Toh  789 27th Street  Las Vegas                  NV  ...
# 2  Christina Lee   123 4th Street   New York                  NY  ...
# 3  Christina Lee   123 4th Street   New York                  NY  ...
# 4  Christina Lee   123 4th Street   New York                  NY  ...
#
#   mobile_phone     fax_number          address       city state_province  \
# 0         None  (123)555-0101  789 27th Street  Las Vegas             NV
# 1         None  (123)555-0101  789 27th Street  Las Vegas             NV
# 2         None  (123)555-0101   123 4th Street   New York             NY
# 3         None  (123)555-0101   123 4th Street   New York             NY
# 4         None  (123)555-0101   123 4th Street   New York             NY
#
#   zip_postal_code country_region  web_page notes_customer  attachments
# 0           99999            USA      None           None          b''
# 1           99999            USA      None           None          b''
# 2           99999            USA      None           None          b''
# 3           99999            USA      None           None          b''
# 4           99999            USA      None           None          b''
#
# [5 rows x 48 columns]

# %%
merged["revenue"] = (
    merged["quantity"]*
    merged["unit_price"]*
    (1 - merged["discount"])
)

# %%
customer_revenue = (
    merged
    .groupby(["customer_id", "company", "country_region","city"], as_index=False)
    ["revenue"]
    .sum()
    .sort_values("revenue", ascending=False)
)

customer_revenue.head(10)
# Out:
#     customer_id     company country_region            city   revenue
# 13           28  Company BB            USA         Memphis  15432.50
# 4             7   Company G            USA           Boise  13800.00
# 3             6   Company F            USA       Milwaukee   8007.50
# 2             4   Company D            USA        New York   4949.00
# 5             8   Company H            USA        Portland   4683.00
# 6             9   Company I            USA  Salt Lake City   3786.50
# 11           26   Company Z            USA           Miami   3625.25
# 14           29  Company CC            USA          Denver   2905.50
# 1             3   Company C            USA     Los Angelas   2550.00
# 0             1   Company A            USA         Seattle   2410.75

# %%
city_revenue = (
    customer_revenue
    .groupby("city", as_index=False)
    ["revenue"]
    .sum()
    .sort_values("revenue", ascending=False)
)

city_revenue
# Out:
#               city   revenue
# 5          Memphis  15432.50
# 0            Boise  13800.00
# 7        Milwaukee   8007.50
# 8         New York   4949.00
# 9         Portland   4683.00
# 6            Miami   4644.75
# 10  Salt Lake City   3786.50
# 2           Denver   2905.50
# 3        Las Vegas   2695.00
# 4      Los Angelas   2550.00
# 11         Seattle   2410.75
# 1          Chicago   2272.50

# %% [markdown]
# top 10 customer bar chart.

# %%
import matplotlib.pyplot as plt

top10 = customer_revenue.head(10)

plt.figure()
plt.barh(top10["company"], top10["revenue"])
plt.xlabel("Total Revenue")
plt.ylabel("Customer Company")
plt.title("Top 10 Revenue Generating Customers")
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# country wise bar chart.

# %%
plt.figure()
plt.bar(city_revenue["city"], city_revenue["revenue"])
plt.xticks(rotation=45)
plt.xlabel("City")
plt.ylabel("Total Revenue")
plt.title("Revenue by Country")
plt.show()

# %% [markdown]
# ### insight

# %% [markdown]
# Analysis show that a small number of customers contribute a large portion of total revenue.
# citys like memphis boise milwaukee new york portland miami ect dominate revenue generstion,
#  indicating storng market presence in those regions.
