# %% [markdown]
# ## category wise revenue distribution

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine(
    "mysql+pymysql://root:Durgesh821@localhost:3306/northwind"
)

products = pd.read_sql("select * from products", engine)
products.head()
# Out:
#   supplier_ids  id product_code                          product_name  \
# 0            4   1       NWTB-1                Northwind Traders Chai
# 1           10   3      NWTCO-3               Northwind Traders Syrup
# 2           10   4      NWTCO-4     Northwind Traders Cajun Seasoning
# 3           10   5       NWTO-5           Northwind Traders Olive Oil
# 4          2;6   6      NWTJP-6  Northwind Traders Boysenberry Spread
#
#   description  standard_cost  list_price  reorder_level  target_level  \
# 0        None        13.5000       18.00             10            40
# 1        None         7.5000       10.00             25           100
# 2        None        16.5000       22.00             10            40
# 3        None        16.0125       21.35             10            40
# 4        None        18.7500       25.00             25           100
#
#      quantity_per_unit  discontinued  minimum_reorder_quantity  \
# ...

# %%
order_details = pd.read_sql("select * from order_details",engine)
order_details.head()
# Out:
#    id  order_id  product_id  quantity  unit_price  discount  status_id  \
# 0  27        30          34     100.0        14.0       0.0          2
# 1  28        30          80      30.0         3.5       0.0          2
# 2  29        31           7      10.0        30.0       0.0          2
# 3  30        31          51      10.0        53.0       0.0          2
# 4  31        31          80      10.0         3.5       0.0          2
#
#   date_allocated  purchase_order_id  inventory_id
# 0           None               96.0          83.0
# 1           None                NaN          63.0
# 2           None                NaN          64.0
# 3           None                NaN          65.0
# 4           None                NaN          66.0

# %%
query ="""select
               p.category,
               sum(od.unit_price * od.quantity *(1 - od.discount)) as total_revenue
               from products p
               join order_details od
               on p.id =od.product_id
               group by p.category
               order by total_revenue desc;

"""

# %%
df = pd.read_sql_query(query,engine)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   category       14 non-null     object
#  1   total_revenue  14 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 356.0+ bytes

# %% [markdown]
# ## visualization(pie chart)

# %%
plt.figure(figsize=(10,6))
plt.pie(df["total_revenue"],labels=df["category"],autopct="%1.1f%%")
plt.title("category-wise revenue distribution")
plt.show()

# %% [markdown]
# ## insight

# %% [markdown]
# ### The revenue distribution is highly skewed toward beverages, which alone contributes overall 56.2% of the
# ### total revenue ,showing strong category dominance . Other categorys contribute relatively smaller share,
# ### indicating revenue concentration risk. this suggest the business is heavily depandent on beverages, while other category offer  opportunities for growth through focused marketing and product expansion.
